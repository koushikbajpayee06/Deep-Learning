# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [0,0,1,1]
or_data['input2'] = [0,1,0,1]
or_data['output'] = [0,1,1,1]

# %%
and_data['input1'] = [0,0,1,1]
and_data['input2'] = [0,1,0,1]
and_data['output'] = [0,0,0,1]

# %%
xor_data['input1'] = [0,0,1,1]
xor_data['input2'] = [0,1,0,1]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       0       0       0
# 1       0       1       0
# 2       1       0       0
# 3       1       1       1

# %%
or_data
# Out:
#    input1  input2  output
# 0       0       0       0
# 1       0       1       1
# 2       1       0       1
# 3       1       1       1

# %%
sns.scatterplot(
    x=and_data['input1'],
    y=and_data['input2'],
    hue=and_data['output'],
    s=100
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(
    x=or_data['input1'],
    y=or_data['input2'],
    hue=or_data['output'],
    s=100
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(
    x=xor_data['input1'],
    y=xor_data['input2'],
    hue=xor_data['output'],
    s=100
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:, :2], and_data['output'])
clf2.fit(or_data.iloc[:, :2], or_data['output'])
clf3.fit(xor_data.iloc[:, :2], xor_data['output'])
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x = np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(
    x=and_data['input1'],
    y=and_data['input2'],
    hue=and_data['output'],
    s=100
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
x1=np.linspace(-1,1,5)
y1=-x1+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(
    x=xor_data['input1'],
    y=xor_data['input2'],
    hue=xor_data['output'],
    s=100
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf3.intercept_
from mlxtend.plotting import plot_decision_regions

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xor_data.iloc[:, 0:2].values,xor_data.iloc[:, -1].values, clf3, legend=2)
# Out:
# d:\Deep Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
