# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initilize_parameters(layer_dims):
    np.random.seed(3)
    parameters = {}
    L = len(layer_dims)
    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) * 0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))
    return parameters

# %%
initilize_parameters([2,2,1])
# Out:
# {'W1': array([[ 0.01788628,  0.0043651 ],
#         [ 0.00096497, -0.01863493]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[-0.00277388, -0.00354759]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):
    Z = np.dot(W, A_prev) + b
    return Z

# %%
def forward_propagation(X, parameters):
    A = X
    L = len(parameters) // 2
    for l in range(1, L + 1):
        A_prev = A
        W = parameters['W' + str(l)]
        b = parameters['b' + str(l)]
        print("A" + str(l-1) + " = ", A_prev)
        print("W" + str(l) + " = ", W)
        print("b" + str(l) + " = ", b)
        print("--" * 20)
        A = linear_forward(A_prev, W, b)
        print("A" + str(l) + " = ", A)
        print("--" * 20)
    return A, A_prev

# %%
X = df[['cgpa','profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]
parameters = initilize_parameters([2,2,1])
y_hat, A1=forward_propagation(X,parameters)
# Out:
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 =  [[0.]
#  [0.]]
# ----------------------------------------
# A1 =  [[ 0.17801107]
#  [-0.14135962]]
# ----------------------------------------
# A1 =  [[ 0.17801107]
#  [-0.14135962]]
# W2 =  [[-0.00277388 -0.00354759]]
# b2 =  [[0.]]
# ----------------------------------------
# A2 =  [[7.70424482e-06]]
# ----------------------------------------

# %%
print("X shape =", X.shape)
print("A1 shape =", A1.shape)

print("W1 shape =", parameters['W1'].shape)
print("b1 shape =", parameters['b1'].shape)

print("W2 shape =", parameters['W2'].shape)
print("b2 shape =", parameters['b2'].shape)
# Out:
# X shape = (2, 1)
# A1 shape = (2, 1)
# W1 shape = (2, 2)
# b1 shape = (2, 1)
# W2 shape = (1, 2)
# b2 shape = (1, 1)

# %%
y_hat = y_hat[0][0]
y_hat
# Out:
# np.float64(7.704244817011694e-06)

# %%
A1
# Out:
# array([[ 0.17801107],
#        [-0.14135962]])

# %%
def update_parameters(parameters, y, y_hat, A1, X):

    # Output layer
    parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat) * A1[0][0])
    parameters['W2'][0][1] = parameters['W2'][0][1] + (0.001 * 2 * (y - y_hat) * A1[1][0])

    parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001 * 2 * (y - y_hat))

    # Hidden neuron 1
    parameters['W1'][0][0] = parameters['W1'][0][0] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][0] * X[0][0]
    )

    parameters['W1'][0][1] = parameters['W1'][0][1] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][0] * X[1][0]
    )

    parameters['b1'][0][0] = parameters['b1'][0][0] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][0]
    )

    # Hidden neuron 2
    parameters['W1'][1][0] = parameters['W1'][1][0] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][1] * X[0][0]
    )

    parameters['W1'][1][1] = parameters['W1'][1][1] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][1] * X[1][0]
    )

    parameters['b1'][1][0] = parameters['b1'][1][0] + (
        0.001 * 2 * (y - y_hat) * parameters['W2'][0][1]
    )

    return parameters

# %%
update_parameters(parameters,y,y_hat,A1,X)
# Out:
# {'W1': array([[ 0.0177999 ,  0.00427871],
#         [ 0.00066555, -0.01893435]]),
#  'b1': array([[-1.07983491e-05],
#         [-3.74276444e-05]]),
#  'W2': array([[-0.0013498 , -0.00467846]]),
#  'b2': array([[0.00799998]])}

# %%
parameters
# Out:
# {'W1': array([[ 0.0177999 ,  0.00427871],
#         [ 0.00066555, -0.01893435]]),
#  'b1': array([[-1.07983491e-05],
#         [-3.74276444e-05]]),
#  'W2': array([[-0.0013498 , -0.00467846]]),
#  'b2': array([[0.00799998]])}

# %%
# epochs implementation
parameters = initilize_parameters([2,2,1])
epochs = 5
for i in range(epochs):
    Loss = []
    for j in range(df.shape[0]):
        X = df[['cgpa','profile_score']].values[j].reshape(2,1)
        y = df[['lpa']].values[j][0]
        y_hat, A1=forward_propagation(X,parameters)
        y_hat = y_hat[0][0]
        Loss.append((y - y_hat) ** 2)
        parameters = update_parameters(parameters,y,y_hat,A1,X)
    print("Epoch -", i+1, "Loss", np.array(Loss).mean())
parameters
# Out:
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 =  [[0.]
#  [0.]]
# ----------------------------------------
# A1 =  [[ 0.17801107]
#  [-0.14135962]]
# ----------------------------------------
# A1 =  [[ 0.17801107]
#  [-0.14135962]]
# W2 =  [[-0.00277388 -0.00354759]]
# b2 =  [[0.]]
# ----------------------------------------
# A2 =  [[7.70424482e-06]]
# ----------------------------------------
# A0 =  [[7]
#  [9]]
# W1 =  [[ 0.0177999   0.00427871]
#  [ 0.00066555 -0.01893435]]
# b1 =  [[-1.07983491e-05]
#  [-3.74276444e-05]]
# ----------------------------------------
# A1 =  [[ 0.16309689]
#  [-0.16578769]]
# ----------------------------------------
# A1 =  [[ 0.16309689]
#  [-0.16578769]]
# W2 =  [[-0.0013498  -0.00467846]]
# b2 =  [[0.00799998]]
# ----------------------------------------
# A2 =  [[0.00855547]]
# ----------------------------------------
# A0 =  [[ 6]
#  [10]]
# W1 =  [[ 0.01781935  0.00430372]
#  [ 0.00022297 -0.01950339]]
# b1 =  [[-8.01929305e-06]
#  [-1.00654319e-04]]
# ----------------------------------------
# A1 =  [[ 0.14994532]
#  [-0.19379674]]
# ----------------------------------------
# A1 =  [[ 0.14994532]
#  [-0.19379674]]
# W2 =  [[ 0.00027838 -0.0063335 ]]
# b2 =  [[0.01798287]]
# ----------------------------------------
# A2 =  [[0.01925203]]
# ----------------------------------------
# A0 =  [[ 5]
#  [12]]
# W1 =  [[ 0.01796805  0.00455156]
#  [-0.00039795 -0.02053825]]
# b1 =  [[ 1.67643559e-05]
#  [-2.04140439e-04]]
# ----------------------------------------
# A1 =  [[ 0.14447575]
#  [-0.24865288]]
# ----------------------------------------
# A1 =  [[ 0.14447575]
#  [-0.24865288]]
# W2 =  [[ 0.00207195 -0.0086516 ]]
# b2 =  [[0.02994437]]
# ----------------------------------------
# A2 =  [[0.03239496]]
# ----------------------------------------
# Epoch - 1 Loss 31.307830783082082
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.0182527   0.00523471]
#  [-0.00124219 -0.02256442]]
# b1 =  [[ 7.36932032e-05]
#  [-3.72988275e-04]]
# ----------------------------------------
# A1 =  [[ 0.18797292]
#  [-0.19082589]]
# ----------------------------------------
# A1 =  [[ 0.18797292]
#  [-0.19082589]]
# W2 =  [[ 0.00408525 -0.01211663]]
# b2 =  [[0.04387958]]
# ----------------------------------------
# A2 =  [[0.04695966]]
# ----------------------------------------
# A0 =  [[7]
#  [9]]
# W1 =  [[ 0.01860508  0.00558709]
#  [-0.00210397 -0.02342621]]
# b1 =  [[ 0.00011774]
#  [-0.00048071]]
# ----------------------------------------
# A1 =  [[ 0.18063709]
#  [-0.22604437]]
# ----------------------------------------
# A1 =  [[ 0.18063709]
#  [-0.22604437]]
# W2 =  [[ 0.00557138 -0.01362532]]
# b2 =  [[0.05178566]]
# ----------------------------------------
# A2 =  [[0.05587199]]
# ----------------------------------------
# A0 =  [[ 6]
#  [10]]
# W1 =  [[ 0.01911435  0.00624187]
#  [-0.0032018  -0.0248377 ]]
# b1 =  [[ 0.00019049]
#  [-0.00063754]]
# ----------------------------------------
# A1 =  [[ 0.17729532]
#  [-0.26822536]]
# ----------------------------------------
# A1 =  [[ 0.17729532]
#  [-0.26822536]]
# W2 =  [[ 0.00735757 -0.0158605 ]]
# b2 =  [[0.06167392]]
# ----------------------------------------
# A2 =  [[0.06723257]]
# ----------------------------------------
# A0 =  [[ 5]
#  [12]]
# W1 =  [[ 0.01978793  0.0073645 ]
#  [-0.00455754 -0.02709727]]
# b1 =  [[ 0.00030276]
#  [-0.0008635 ]]
# ----------------------------------------
# A1 =  [[ 0.18761642]
#  [-0.34881847]]
# ----------------------------------------
# A1 =  [[ 0.18761642]
#  [-0.34881847]]
# W2 =  [[ 0.00946127 -0.01904314]]
# b2 =  [[0.07353945]]
# ----------------------------------------
# A2 =  [[0.08195714]]
# ----------------------------------------
# Epoch - 2 Loss 30.78199403553497
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.02062205  0.00936638]
#  [-0.00620884 -0.03106038]]
# b1 =  [[ 0.00046958]
#  [-0.00119376]]
# ----------------------------------------
# A1 =  [[ 0.24037707]
#  [-0.29934755]]
# ----------------------------------------
# A1 =  [[ 0.24037707]
#  [-0.29934755]]
# W2 =  [[ 0.01205715 -0.02386942]]
# b2 =  [[0.08737554]]
# ----------------------------------------
# A2 =  [[0.09741905]]
# ----------------------------------------
# A0 =  [[7]
#  [9]]
# W1 =  [[ 0.02149207  0.0102364 ]
#  [-0.00784517 -0.03269671]]
# b1 =  [[ 0.00057833]
#  [-0.0013983 ]]
# ----------------------------------------
# A1 =  [[ 0.2431504]
#  [-0.3505849]]
# ----------------------------------------
# A1 =  [[ 0.2431504]
#  [-0.3505849]]
# W2 =  [[ 0.01393333 -0.02620588]]
# b2 =  [[0.0951807]]
# ----------------------------------------
# A2 =  [[0.10775598]]
# ----------------------------------------
# A0 =  [[ 6]
#  [10]]
# W1 =  [[ 0.02260933  0.01167288]
#  [-0.00987499 -0.03530649]]
# b1 =  [[ 0.00073794]
#  [-0.00168828]]
# ----------------------------------------
# A1 =  [[ 0.2531227 ]
#  [-0.41400309]]
# ----------------------------------------
# A1 =  [[ 0.2531227 ]
#  [-0.41400309]]
# W2 =  [[ 0.01631243 -0.02963617]]
# b2 =  [[0.10496519]]
# ----------------------------------------
# A2 =  [[0.1213637]]
# ----------------------------------------
# A0 =  [[ 5]
#  [12]]
# W1 =  [[ 0.02397001  0.01394068]
#  [-0.01230901 -0.03936318]]
# b1 =  [[ 0.00096472]
#  [-0.00209395]]
# ----------------------------------------
# A1 =  [[ 0.28810287]
#  [-0.53599719]]
# ----------------------------------------
# A1 =  [[ 0.28810287]
#  [-0.53599719]]
# W2 =  [[ 0.01928846 -0.03450372]]
# b2 =  [[0.11672246]]
# ----------------------------------------
# A2 =  [[0.14077342]]
# ----------------------------------------
# Epoch - 3 Loss 30.19288591268238
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.02556414  0.01776661]
#  [-0.01518006 -0.0462537 ]]
# b1 =  [[ 0.00128355]
#  [-0.00266816]]
# ----------------------------------------
# A1 =  [[ 0.34792958]
#  [-0.49413828]]
# ----------------------------------------
# A1 =  [[ 0.34792958]
#  [-0.49413828]]
# W2 =  [[ 0.02324079 -0.04185677]]
# b2 =  [[0.13044091]]
# ----------------------------------------
# A2 =  [[0.1592101]]
# ----------------------------------------
# A0 =  [[7]
#  [9]]
# W1 =  [[ 0.02715659  0.01935906]
#  [-0.01798553 -0.04905917]]
# b1 =  [[ 0.00148261]
#  [-0.00301884]]
# ----------------------------------------
# A1 =  [[ 0.36581029]
#  [-0.57045011]]
# ----------------------------------------
# A1 =  [[ 0.36581029]
#  [-0.57045011]]
# W2 =  [[ 0.02591344 -0.04565253]]
# b2 =  [[0.13812249]]
# ----------------------------------------
# A2 =  [[0.17364439]]
# ----------------------------------------
# A0 =  [[ 6]
#  [10]]
# W1 =  [[ 0.02914613  0.02191703]
#  [-0.02144229 -0.05350357]]
# b1 =  [[ 0.00176682]
#  [-0.00351266]]
# ----------------------------------------
# A1 =  [[ 0.39581391]
#  [-0.66720212]]
# ----------------------------------------
# A1 =  [[ 0.39581391]
#  [-0.66720212]]
# W2 =  [[ 0.0294445  -0.05115893]]
# b2 =  [[0.1477752]]
# ----------------------------------------
# A2 =  [[0.19356309]]
# ----------------------------------------
# A0 =  [[ 5]
#  [12]]
# W1 =  [[ 0.03151801  0.02587017]
#  [-0.02554677 -0.06034438]]
# b1 =  [[ 0.00216214]
#  [-0.00419674]]
# ----------------------------------------
# A1 =  [[ 0.4701943]
#  [-0.8560631]]
# ----------------------------------------
# A1 =  [[ 0.4701943]
#  [-0.8560631]]
# W2 =  [[ 0.03404104 -0.05890706]]
# b2 =  [[0.15938808]]
# ----------------------------------------
# A2 =  [[0.22582214]]
# ----------------------------------------
# Epoch - 4 Loss 29.412392699331615
# A0 =  [[8]
#  [8]]
# W1 =  [[ 0.03425555  0.03244027]
#  [-0.03032292 -0.07180715]]
# b1 =  [[ 0.00270965]
#  [-0.00515197]]
# ----------------------------------------
# A1 =  [[ 0.53627624]
#  [-0.82219254]]
# ----------------------------------------
# A1 =  [[ 0.53627624]
#  [-0.82219254]]
# W2 =  [[ 0.0404114  -0.07050531]]
# b2 =  [[0.17293643]]
# ----------------------------------------
# A2 =  [[0.25257704]]
# ----------------------------------------
# A0 =  [[7]
#  [9]]
# W1 =  [[ 0.03691956  0.03510428]
#  [-0.03491981 -0.07640404]]
# b1 =  [[ 0.00304265]
#  [-0.00572658]]
# ----------------------------------------
# A1 =  [[ 0.57741812]
#  [-0.93780161]]
# ----------------------------------------
# A1 =  [[ 0.57741812]
#  [-0.93780161]]
# W2 =  [[ 0.0444307  -0.07666751]]
# b2 =  [[0.18043128]]
# ----------------------------------------
# A2 =  [[0.27798529]]
# ----------------------------------------
# A0 =  [[ 6]
#  [10]]
# W1 =  [[ 0.0402173   0.03934422]
#  [-0.04057366 -0.08367327]]
# b1 =  [[ 0.00351375]
#  [-0.00653428]]
# ----------------------------------------
# A1 =  [[ 0.63825975]
#  [-1.08670894]]
# ----------------------------------------
# A1 =  [[ 0.63825975]
#  [-1.08670894]]
# W2 =  [[ 0.04988386 -0.08552414]]
# b2 =  [[0.18987531]]
# ----------------------------------------
# A2 =  [[0.31465401]]
# ----------------------------------------
# A0 =  [[ 5]
#  [12]]
# W1 =  [[ 0.04411571  0.04584158]
#  [-0.04725149 -0.09480299]]
# b1 =  [[ 0.00416349]
#  [-0.00764725]]
# ----------------------------------------
# A1 =  [[ 0.77484107]
#  [-1.38154061]]
# ----------------------------------------
# A1 =  [[ 0.77484107]
#  [-1.38154061]]
# W2 =  [[ 0.05714131 -0.09788077]]
# b2 =  [[0.201246]]
# ----------------------------------------
# A2 =  [[0.3807477]]
# ----------------------------------------
# Epoch - 5 Loss 28.119565443234457
# {'W1': array([[ 0.04857703,  0.05654874],
#         [-0.0549411 , -0.11325804]]),
#  'b1': array([[ 0.00505575],
#         [-0.00918517]]),
#  'W2': array([[ 0.06739905, -0.1161703 ]]),
#  'b2': array([[0.21448451]])}
